# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
custom_data = pd.read_json('experiment_custom.json')
json_data = pd.read_json('experiment_json.json')

# %%
custom_data
# Out:
#                                                message  message_size  \
# 0                                                a|b|a            42
# 1                                                a|b|a            42
# 2                                                a|b|a            42
# 3                                                a|b|a            42
# 4                                                a|b|a            42
# ..                                                 ...           ...
# 995  a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          1032
# 996  a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          1032
# 997  a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          1032
# 998  a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          1032
# 999  a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          1032
#
#      response_size  time_taken
# 0               77    0.000292
# 1               77    0.000133
# 2               77    0.000143
# 3               77    0.000113
# 4               77    0.000121
# ..             ...         ...
# 995             77    0.000106
# 996             77    0.000112
# 997             77    0.000117
# 998             77    0.000107
# 999             77    0.000124
#
# [1000 rows x 4 columns]

# %%
custom_avg = custom_data.groupby('message').mean()
custom_avg
# Out:
#                                                     message_size  \
# message
# a|b|a                                                       42.0
# a|b|aaaaaaaaaaa                                             52.0
# a|b|aaaaaaaaaaaaaaaaaaaaa                                   62.0
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa                         72.0
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa               82.0
# ...                                                          ...
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...         992.0
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1002.0
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1012.0
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1022.0
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1032.0
#
#                                                     response_size  time_taken
# message
# a|b|a                                                        77.0    0.000138
# a|b|aaaaaaaaaaa                                              77.0    0.000097
# a|b|aaaaaaaaaaaaaaaaaaaaa                                    77.0    0.000088
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa                          77.0    0.000092
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa                77.0    0.000098
# ...                                                           ...         ...
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...           77.0    0.000120
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...           77.0    0.000124
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...           77.0    0.000120
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...           77.0    0.000120
# a|b|aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...           77.0    0.000117
#
# [100 rows x 3 columns]

# %%
json_avg = json_data.groupby('message').mean()
json_avg
# Out:
#                                                     message_size  \
# message
# a                                                           98.0
# aaaaaaaaaaa                                                108.0
# aaaaaaaaaaaaaaaaaaaaa                                      118.0
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa                            128.0
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa                  138.0
# ...                                                          ...
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1048.0
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1058.0
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1068.0
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1078.0
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...        1088.0
#
#                                                     response_size  time_taken
# message
# a                                                           141.0    0.000614
# aaaaaaaaaaa                                                 141.0    0.000235
# aaaaaaaaaaaaaaaaaaaaa                                       141.0    0.000264
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa                             141.0    0.000316
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa                   141.0    0.000343
# ...                                                           ...         ...
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          141.0    0.004834
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          141.0    0.004902
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          141.0    0.004933
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          141.0    0.004970
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa...          141.0    0.005035
#
# [100 rows x 3 columns]

# %%
plt.plot(list(range(1, 1001,10)), custom_avg['message_size'], label='custom protocol')
plt.plot(list(range(1, 1001,10)), json_avg['message_size'], label='json protocol')
plt.legend()
plt.title("size of the message sent from client to server vs number of characters in sender's message")
# Out:
# Text(0.5, 1.0, "size of the message sent from client to server vs number of characters in sender's message")

# %% [markdown]
# Makes sense that above would be a linear relationship

# %%
plt.plot(list(range(1, 1001,10)), custom_avg['response_size'], label='custom protocol')
plt.plot(list(range(1, 1001,10)), json_avg['response_size'], label='json protocol')
plt.legend()
plt.title("size of the response sent from server to client vs number of characters in sender's message")
# Out:
# Text(0.5, 1.0, "size of the response sent from server to client vs number of characters in sender's message")

# %%
plt.plot(list(range(1, 1001,10)), custom_avg['time_taken'], label='custom protocol')
plt.plot(list(range(1, 1001,10)), json_avg['time_taken'], label='json protocol')
plt.legend()
plt.title("time taken averaged over 10 trials vs number of characters in sender's message")
# Out:
# Text(0.5, 1.0, "time taken averaged over 10 trials vs number of characters in sender's message")
